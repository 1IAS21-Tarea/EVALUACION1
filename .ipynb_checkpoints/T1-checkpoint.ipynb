# %%
# links to websites
territoryLink='https://www.citypopulation.de/en/world/bymap/landarea/'
birthRateLink='https://www.cia.gov/the-world-factbook/about/archives/2021/field/birth-rate/country-comparison'
energyLink='https://www.worldometers.info/energy/'

# scrapping into LIST of Dataframes

import pandas as pd

territoryList=pd.read_html(territoryLink,header=0,flavor='bs4')
birthRateList=pd.read_html(birthRateLink,header=0,flavor='bs4')
energyList=pd.read_html(energyLink,header=0,flavor='bs4')

# %%
# getting the Dataframe from list
territory=territoryList[0]
birthRate=birthRateList[0]
energy=energyList[0]

# %%
territory
# Out:
#      Rank (total)                   Country  Total (square km)  \
# 0             1.0                    Russia         16377742.0
# 1             2.0                Antarctica         14200000.0
# 2             3.0                     China          9326410.0
# 3             4.0  United States of America          9147593.0
# 4             5.0                    Canada          9093507.0
# ..            ...                       ...                ...
# 250         250.0           Spratly Islands                5.0
# 251         252.0         Coral Sea Islands                3.0
# 252         253.0                    Monaco                2.0
# 253         254.0              Vatican City                0.4
# 254           NaN                     World        148940000.0
#
#     per Capita (square m)  Date
# 0                  113358  2018
# 1                     ...  2018
# 2                    6696  2018
# 3                   27960  2018
# 4                  245380  2018
# ..                    ...   ...
# 250                   ...  2018
# 251                   ...  2018
# 252                    53  2018
# 253                   530  2018
# 254                 19849  2018
#
# [255 rows x 5 columns]

# %%
birthRate
# Out:
#      Rank                    Country  births/1,000 population  \
# 0       1                      Niger                    47.28
# 1       2                     Angola                    42.22
# 2       3                       Mali                    41.60
# 3       4                     Uganda                    41.60
# 4       5                      Benin                    41.55
# ..    ...                        ...                      ...
# 222   224                      Japan                     7.00
# 223   225                    Andorra                     6.91
# 224   226               Korea, South                     6.89
# 225   227                     Monaco                     6.63
# 226   228  Saint Pierre and Miquelon                     6.58
#
#     Date of Information
# 0             2021 est.
# 1             2021 est.
# 2             2021 est.
# 3             2021 est.
# 4             2021 est.
# ..                  ...
# 222           2021 est.
# 223           2021 est.
# 224           2021 est.
# 225           2021 est.
# 226           2021 est.
#
# [227 rows x 4 columns]

# %%
energy
# Out:
#        #                  Country  Energy  Consumption (BTU) World  Share  \
# 0      1                    China            138689472800000        23.8%
# 1      2            United States             97661161460000        16.8%
# 2      3                   Russia             32832743720000         5.6%
# 3      4                    India             30476788610000         5.2%
# 4      5                    Japan             19402928820000         3.3%
# ..   ...                      ...                        ...          ...
# 204  205  Saint Pierre & Miquelon                 1982000000     0.00034%
# 205  206                    Tonga                 1807000000     0.00031%
# 206  207             Cook Islands                 1677278000     0.00029%
# 207  208         Falkland Islands                   82900000     0.00001%
# 208  209                 Kiribati                   46100000     0.00001%
#
#      Per capita Yearly BTU
# 0                    98342
# 1                   296130
# 2                   225728
# 3                    22505
# 4                   153186
# ..                     ...
# 204                 332718
# 205                  17142
# 206                  96423
# 207                  23041
# 208                    383
#
# [209 rows x 5 columns]

# %%
territory.shape,birthRate.shape,energy.shape
# Out:
# ((255, 5), (227, 4), (209, 5))

# %%
territory.columns,birthRate.columns,energy.columns
# Out:
# (Index(['Rank (total)', 'Country', 'Total (square km)', 'per Capita (square m)',
#         'Date'],
#        dtype='object'),
#  Index(['Rank', 'Country', 'births/1,000 population', 'Date of Information'], dtype='object'),
#  Index(['#', 'Country', 'Energy  Consumption (BTU)', 'World  Share',
#         'Per capita Yearly BTU'],
#        dtype='object'))

# %%
# how many resulting rows after inner merging
territory.merge(birthRate,how='inner',left_on='Country',right_on='Country').shape
# Out:
# (207, 8)

# %%
# Countries in 'cia' but NOT in 'fragile2019' 
OnlyCia=set(cia.Country)-set(fragile2019.Country)
OnlyCia

# %%
# First merge -> between territory and birthRate
merge1=territory.merge(birthRate,left_on='Country',right_on='Country')
merge1
# Out:
#      Rank (total)           Country  Total (square km) per Capita (square m)  \
# 0             1.0            Russia         16377742.0                113358
# 1             3.0             China          9326410.0                  6696
# 2             5.0            Canada          9093507.0                245380
# 3             6.0            Brazil          8358140.0                 40088
# 4             7.0         Australia          7682300.0                307380
# ..            ...               ...                ...                   ...
# 202         240.0            Tuvalu               25.6                  2433
# 203         241.0  Saint Barthelemy               25.0                  2475
# 204         243.0             Nauru               21.2                  1868
# 205         246.0         Gibraltar                6.5                   188
# 206         253.0            Monaco                2.0                    53
#
#      Date  Rank  births/1,000 population Date of Information
# 0    2018   193                     9.71           2021 est.
# 1    2018   169                    11.30           2021 est.
# 2    2018   190                    10.21           2021 est.
# 3    2018   136                    13.44           2021 est.
# 4    2018   154                    12.35           2021 est.
# ..    ...   ...                      ...                 ...
# 202  2018    54                    22.97           2021 est.
# 203  2018   200                     9.27           2021 est.
# 204  2018    66                    21.49           2021 est.
# 205  2018   132                    13.99           2021 est.
# 206  2018   227                     6.63           2021 est.
#
# [207 rows x 8 columns]

# %%
merge1.merge(energy,how='inner',left_on='Country',right_on='Country').shape
# Out:
# (180, 12)

# %%
# second merge -> between merge1 and energy
merge2=merge1.merge(energy,left_on='Country',right_on='Country')
merge2
# Out:
#      Rank (total)                 Country  Total (square km)  \
# 0             1.0                  Russia         16377742.0
# 1             3.0                   China          9326410.0
# 2             5.0                  Canada          9093507.0
# 3             6.0                  Brazil          8358140.0
# 4             7.0               Australia          7682300.0
# ..            ...                     ...                ...
# 175         221.0            Cook Islands              236.0
# 176         224.0                   Aruba              180.0
# 177         226.0  British Virgin Islands              151.0
# 178         235.0                 Bermuda               53.6
# 179         246.0               Gibraltar                6.5
#
#     per Capita (square m)  Date  Rank  births/1,000 population  \
# 0                  113358  2018   193                     9.71
# 1                    6696  2018   169                    11.30
# 2                  245380  2018   190                    10.21
# 3                   40088  2018   136                    13.44
# 4                  307380  2018   154                    12.35
# ..                    ...   ...   ...                      ...
# 175                 15128  2018   142                    12.85
# 176                  1615  2018   159                    11.95
# 177                  4519  2018   176                    10.98
# 178                   839  2018   174                    11.10
# 179                   188  2018   132                    13.99
#
#     Date of Information    #  Energy  Consumption (BTU) World  Share  \
# 0             2021 est.    3             32832743720000         5.6%
# 1             2021 est.    1            138689472800000        23.8%
# 2             2021 est.    6             15062124200000         2.6%
# 3             2021 est.    9             12566399560000         2.2%
# 4             2021 est.   18              6127579421000     1.05218%
# ..                  ...  ...                        ...          ...
# 175           2021 est.  207                 1677278000     0.00029%
# 176           2021 est.  167                17606311000     0.00302%
# 177           2021 est.  199                 3397977000     0.00058%
# 178           2021 est.  182                11252000000     0.00193%
# 179           2021 est.  106               192833000000      0.0331%
#
#      Per capita Yearly BTU
# 0                   225728
# 1                    98342
# 2                   412047
# 3                    60269
# 4                   249187
# ..                     ...
# 175                  96423
# 176                 166981
# 177                 113040
# 178                 177827
# 179                5914760
#
# [180 rows x 12 columns]

# %%
#subir el archivo entregado por el profesor
import os
country_isos=pd.read_excel(os.path.join('country_isos.xlsx'))

# %%
country_isos
# Out:
#                  Country                            Officialstatename  \
# 0            AFGHANISTAN          The Islamic Republic of Afghanistan
# 1                ALBANIA                      The Republic of Albania
# 2                ALGERIA  The People's Democratic Republic of Algeria
# 3                 ANGOLA                       The Republic of Angola
# 4    ANTIGUA AND BARBUDA                          Antigua and Barbuda
# ..                   ...                                          ...
# 166           UZBEKISTAN                   The Republic of Uzbekistan
# 167             VIET NAM           The Socialist Republic of Viet Nam
# 168                YEMEN                        The Republic of Yemen
# 169               ZAMBIA                       The Republic of Zambia
# 170             ZIMBABWE                     The Republic of Zimbabwe
#
#     InternetccTLD iso2 iso3
# 0             .af   AF  AFG
# 1             .al   AL  ALB
# 2             .dz   DZ  DZA
# 3             .ao   AO  AGO
# 4             .ag   AG  ATG
# ..            ...  ...  ...
# 166           .uz   UZ  UZB
# 167           .vn   VN  VNM
# 168           .ye   YE  YEM
# 169           .zm   ZM  ZMB
# 170           .zw   ZW  ZWE
#
# [171 rows x 5 columns]

# %%
country_isos.shape
# Out:
# (171, 5)

# %%
country_isos.columns
# Out:
# Index(['Country', 'Officialstatename', 'InternetccTLD', 'iso2', 'iso3'], dtype='object')

# %%
merge2.merge(country_isos,how='inner',left_on='Country',right_on='Country').shape
# Out:
# (0, 16)

# %%
# modify the 'Country' column of the 'merge2' dataframe so that it is in UPPER LETTERS
merge2_copy = merge2.copy()
merge2_copy['Country'] = merge2_copy['Country'].str.upper()
merge2_copy
# Out:
#      Rank (total)                 Country  Total (square km)  \
# 0             1.0                  RUSSIA         16377742.0
# 1             3.0                   CHINA          9326410.0
# 2             5.0                  CANADA          9093507.0
# 3             6.0                  BRAZIL          8358140.0
# 4             7.0               AUSTRALIA          7682300.0
# ..            ...                     ...                ...
# 175         221.0            COOK ISLANDS              236.0
# 176         224.0                   ARUBA              180.0
# 177         226.0  BRITISH VIRGIN ISLANDS              151.0
# 178         235.0                 BERMUDA               53.6
# 179         246.0               GIBRALTAR                6.5
#
#     per Capita (square m)  Date  Rank  births/1,000 population  \
# 0                  113358  2018   193                     9.71
# 1                    6696  2018   169                    11.30
# 2                  245380  2018   190                    10.21
# 3                   40088  2018   136                    13.44
# 4                  307380  2018   154                    12.35
# ..                    ...   ...   ...                      ...
# 175                 15128  2018   142                    12.85
# 176                  1615  2018   159                    11.95
# 177                  4519  2018   176                    10.98
# 178                   839  2018   174                    11.10
# 179                   188  2018   132                    13.99
#
#     Date of Information    #  Energy  Consumption (BTU) World  Share  \
# 0             2021 est.    3             32832743720000         5.6%
# 1             2021 est.    1            138689472800000        23.8%
# 2             2021 est.    6             15062124200000         2.6%
# 3             2021 est.    9             12566399560000         2.2%
# 4             2021 est.   18              6127579421000     1.05218%
# ..                  ...  ...                        ...          ...
# 175           2021 est.  207                 1677278000     0.00029%
# 176           2021 est.  167                17606311000     0.00302%
# 177           2021 est.  199                 3397977000     0.00058%
# 178           2021 est.  182                11252000000     0.00193%
# 179           2021 est.  106               192833000000      0.0331%
#
#      Per capita Yearly BTU
# 0                   225728
# 1                    98342
# 2                   412047
# 3                    60269
# 4                   249187
# ..                     ...
# 175                  96423
# 176                 166981
# 177                 113040
# 178                 177827
# 179                5914760
#
# [180 rows x 12 columns]

# %%
merge2_copy.merge(country_isos,how='inner',left_on='Country',right_on='Country').shape
# Out:
# (140, 16)

# %%
# third merge -> between merge2_copy and country_isos
merge3=country_isos.merge(merge2_copy,left_on='Country',right_on='Country')
merge3
# Out:
#                  Country                            Officialstatename  \
# 0            AFGHANISTAN          The Islamic Republic of Afghanistan
# 1                ALBANIA                      The Republic of Albania
# 2                ALGERIA  The People's Democratic Republic of Algeria
# 3                 ANGOLA                       The Republic of Angola
# 4    ANTIGUA AND BARBUDA                          Antigua and Barbuda
# ..                   ...                                          ...
# 135              URUGUAY             The Oriental Republic of Uruguay
# 136           UZBEKISTAN                   The Republic of Uzbekistan
# 137                YEMEN                        The Republic of Yemen
# 138               ZAMBIA                       The Republic of Zambia
# 139             ZIMBABWE                     The Republic of Zimbabwe
#
#     InternetccTLD iso2 iso3  Rank (total)  Total (square km)  \
# 0             .af   AF  AFG          42.0           652230.0
# 1             .al   AL  ALB         148.0            27398.0
# 2             .dz   DZ  DZA          11.0          2381740.0
# 3             .ao   AO  AGO          24.0          1246700.0
# 4             .ag   AG  ATG         205.0              442.6
# ..            ...  ...  ...           ...                ...
# 135           .uy   UY  URY          92.0           175015.0
# 136           .uz   UZ  UZB          59.0           425400.0
# 137           .ye   YE  YEM          51.0           527968.0
# 138           .zm   ZM  ZMB          40.0           743398.0
# 139           .zw   ZW  ZWE          62.0           386847.0
#
#     per Capita (square m)  Date  Rank  births/1,000 population  \
# 0                   20657  2018    13                    36.08
# 1                    9558  2018   141                    12.86
# 2                   55938  2018    76                    19.24
# 3                   42622  2018     2                    42.22
# 4                    4649  2018   115                    15.30
# ..                    ...   ...   ...                      ...
# 135                 49919  2018   145                    12.75
# 136                 12908  2018   109                    15.85
# 137                 18417  2018    47                    25.21
# 138                 44020  2018    17                    35.23
# 139                 28236  2018    23                    33.34
#
#     Date of Information    #  Energy  Consumption (BTU) World  Share  \
# 0             2021 est.  119               144694375000      0.0248%
# 1             2021 est.  128               111843460000      0.0192%
# 2             2021 est.   36              2398447784000     0.41184%
# 3             2021 est.   85               362803130000      0.0623%
# 4             2021 est.  184                10605278000     0.00182%
# ..                  ...  ...                        ...          ...
# 135           2021 est.  103               219406294000      0.0377%
# 136           2021 est.   42              1798254680000     0.30878%
# 137           2021 est.  120               138496775000      0.0238%
# 138           2021 est.  110               177977721000      0.0306%
# 139           2021 est.  115               158453760000      0.0272%
#
#      Per capita Yearly BTU
# 0                     4059
# 1                    38843
# 2                    58305
# 3                    12010
# 4                   116389
# ..                     ...
# 135                  64113
# 136                  56291
# 137                   4611
# 138                  10289
# 139                  10742
#
# [140 rows x 16 columns]
